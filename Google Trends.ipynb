# %% [markdown]
# <h1>Combine Google Trends with other Time Series Data</h1>

# %%
# What can the popularity of search terms tell us about the world? 
# Google Trends gives us access to the popularity of Google Search terms. Let's investigate:

# 1. How search volume for "Bitcoin" relates to the price of Bitcoin

# 2. How search volume for a hot stock like Telsa relates to that stock's price and

# 3. How searches for "Unemployment Benefits" vary with the actual unemployment rate in the United States

# %%
import pandas as pd

# Reading cvs files:

# TESLA SEARCH:
df_tesla = pd.read_csv('D:\\Desktop\\Study\\100 Days of Code - The Complete Python Pro Bootcamp for 2021\\DATA\\Google Trends\\TESLA Search Trend vs Price.csv')
df_tesla.head()
# Out:
#         MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0  2010-06-01                3           4.766
# 1  2010-07-01                3           3.988
# 2  2010-08-01                2           3.896
# 3  2010-09-01                2           4.082
# 4  2010-10-01                2           4.368

# %%
df_tesla.tail()
# Out:
#           MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 119  2020-05-01               16      167.000000
# 120  2020-06-01               17      215.962006
# 121  2020-07-01               24      286.152008
# 122  2020-08-01               23      498.320007
# 123  2020-09-01               31      407.339996

# %%
# What are the shapes of the Tesla Search DataFrame?
df_tesla.shape
# Out:
# (124, 3)

# %%
print(f'Largest value for Tesla in Web Search: {df_tesla.TSLA_WEB_SEARCH.max()}')
print(f'Smallest value for Tesla in Web Search: {df_tesla.TSLA_WEB_SEARCH.min()}')
# Out:
# Largest value for Tesla in Web Search: 31
# Smallest value for Tesla in Web Search: 2

# %%
# DESCRIBE() FUNCTION:
# One of the most useful functions to run on DataFrames is .describe(). 
# If you use df_tesla.describe(), you get a whole bunch of descriptive statistics.

df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
# UNEMPLOYMENT BENEFITS 2004-2019:
df_unemployment_2004_19 = pd.read_csv('D:\\Desktop\\Study\\100 Days of Code - The Complete Python Pro Bootcamp for 2021\\DATA\\Google Trends\\UE Benefits Search vs UE Rate 2004-19.csv')
df_unemployment_2004_19.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6

# %%
df_unemployment_2004_19.tail()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 176  2018-09                      14     3.7
# 177  2018-10                      15     3.8
# 178  2018-11                      16     3.7
# 179  2018-12                      17     3.9
# 180  2019-01                      21     4.0

# %%
# What are the shapes of the  UNEMPLOYMENT BENEFITS 2004-2019 DataFrame?
df_unemployment_2004_19.shape
# Out:
# (181, 3)

# %%
print(f'Largest value for "Unemployment Benefits" in Web Search: {df_unemployment_2004_19.UE_BENEFITS_WEB_SEARCH.max()}')
print(f'Smalest value for "Unemployment Benefits" in Web Search: {df_unemployment_2004_19.UE_BENEFITS_WEB_SEARCH.min()}')
# Out:
# Largest value for "Unemployment Benefits" in Web Search: 100
# Smalest value for "Unemployment Benefits" in Web Search: 14

# %%
df_unemployment_2004_19.describe()
# Out:
#        UE_BENEFITS_WEB_SEARCH      UNRATE
# count              181.000000  181.000000
# mean                35.110497    6.217680
# std                 20.484925    1.891859
# min                 14.000000    3.700000
# 25%                 21.000000    4.700000
# 50%                 26.000000    5.400000
# 75%                 45.000000    7.800000
# max                100.000000   10.000000

# %%
# UNEMPLOYMENT BENEFITS 2004-2020:
df_unemployment_2004_20 = pd.read_csv('D:\\Desktop\\Study\\100 Days of Code - The Complete Python Pro Bootcamp for 2021\\DATA\\Google Trends\\UE Benefits Search vs UE Rate 2004-20.csv')
df_unemployment_2004_20.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                       9     5.7
# 1  2004-02                       8     5.6
# 2  2004-03                       7     5.8
# 3  2004-04                       8     5.6
# 4  2004-05                       6     5.6

# %%
df_unemployment_2004_20.tail()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 195  2020-04                     100    14.7
# 196  2020-05                      63    13.3
# 197  2020-06                      53    11.1
# 198  2020-07                      54    10.2
# 199  2020-08                      50     8.4

# %%
# What are the shapes of the  UNEMPLOYMENT BENEFITS 2004-2020 DataFrame?
df_unemployment_2004_20.shape
# Out:
# (200, 3)

# %%
# Bitcoin Search Trend:
df_bitcoin_search_trend = pd.read_csv('D:\\Desktop\\Study\\100 Days of Code - The Complete Python Pro Bootcamp for 2021\\DATA\\Google Trends\\Bitcoin Search Trend.csv')
df_bitcoin_search_trend.head()
# Out:
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
df_bitcoin_search_trend.tail()
# Out:
#       MONTH  BTC_NEWS_SEARCH
# 68  2020-05               22
# 69  2020-06               13
# 70  2020-07               14
# 71  2020-08               16
# 72  2020-09               13

# %%
# What are the shapes of the Bitcoin Search Trend DataFrame?
df_bitcoin_search_trend.shape
# Out:
# (73, 2)

# %%
print(f'Largest value for Bitcoin News Search: {df_bitcoin_search_trend.BTC_NEWS_SEARCH.max()}')
print(f'Smalest value for Bitcoin News Search: {df_bitcoin_search_trend.BTC_NEWS_SEARCH.min()}')
# Out:
# Largest value for Bitcoin News Search: 100
# Smalest value for Bitcoin News Search: 3

# %%
# Using describe() function:
df_bitcoin_search_trend.describe()
# Out:
#        BTC_NEWS_SEARCH
# count        73.000000
# mean         15.013699
# std          15.146959
# min           3.000000
# 25%           5.000000
# 50%          14.000000
# 75%          18.000000
# max         100.000000

# %%
# Daily Bitcoin Price:
df_daily_bitcoin_price = pd.read_csv('D:\\Desktop\\Study\\100 Days of Code - The Complete Python Pro Bootcamp for 2021\\DATA\\Google Trends\\Daily Bitcoin Price.csv')
df_daily_bitcoin_price.head()
# Out:
#          DATE       CLOSE      VOLUME
# 0  2014-09-17  457.334015  21056800.0
# 1  2014-09-18  424.440002  34483200.0
# 2  2014-09-19  394.795990  37919700.0
# 3  2014-09-20  408.903992  36863600.0
# 4  2014-09-21  398.821014  26580100.0

# %%
df_daily_bitcoin_price.tail()
# Out:
#             DATE         CLOSE        VOLUME
# 2199  2020-09-24  10745.548828  2.301754e+10
# 2200  2020-09-25  10702.290039  2.123255e+10
# 2201  2020-09-26  10754.437500  1.810501e+10
# 2202  2020-09-27  10774.426758  1.801688e+10
# 2203  2020-09-28  10912.536133  2.122653e+10

# %%
# What are the shapes of the Daily Bitcoin Price DataFrame?
df_daily_bitcoin_price.shape
# Out:
# (2204, 3)

# %%
df_daily_bitcoin_price.describe()
# Out:
#               CLOSE        VOLUME
# count   2203.000000  2.203000e+03
# mean    4429.421245  8.043622e+09
# std     4148.150071  1.176529e+10
# min      178.102997  5.914570e+06
# 25%      433.629502  6.029915e+07
# 50%     3637.520020  2.018890e+09
# 75%     7997.372803  1.322478e+10
# max    19497.400391  7.415677e+10

# %% [markdown]
# # What do the Search Numbers mean?

# %% [markdown]
# We can see from our DataFrames that Google's search interest ranges between 0 and 100. But what does that mean? Google defines the values of search interest as:
#
# Numbers represent search interest relative to the highest point on the chart for the given region and time. A value of 100 is the peak popularity for the term. A value of 50 means that the term is half as popular. A score of 0 means there was not enough data for this term.
#
# Basically, the actual search volume of a term is not publicly available. Google only offers a scaled number. Each data point is divided by the total searches of the geography and time range it represents to compare relative popularity.
#
#
#
# For each word in your search, Google finds how much search volume in each region and time period your term had relative to all the searches in that region and time period. It then combines all of these measures into a single measure of popularity, and then it scales the values across your topics, so the largest measure is set to 100. In short: Google Trends doesn’t exactly tell you how many searches occurred for your topic, but it does give you a nice proxy.

# %% [markdown]
# Here are the Google Trends Search Parameters that were used to generate the .csv data:
#
# "Tesla", Worldwide, Web Search
#
# "Bitcoin", Worldwide, News Search
#
# "Unemployment Benefits", United States, Web Search

# %% [markdown]
# # Data Cleaning - Resampling Time Series Data

# %%
# First, we have to identify if there are any missing or junk values in our DataFrames.

# 1. Can you investigate all 4 DataFrames and find if there are any missing values? 

# 2. If yes, find how many missing or NaN values there are. Then, find the row where the missing values occur.

# 3. Finally, remove any rows that contain missing values.

# %% [markdown]
# # Find Missing Data (NaN)

# %%
# ANY MISSING DATA?
df_tesla.head()
# Out:
#         MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0  2010-06-01                3           4.766
# 1  2010-07-01                3           3.988
# 2  2010-08-01                2           3.896
# 3  2010-09-01                2           4.082
# 4  2010-10-01                2           4.368

# %%
df_tesla.isna().any()
# Out:
# MONTH              False
# TSLA_WEB_SEARCH    False
# TSLA_USD_CLOSE     False
# dtype: bool

# %%
# ANY MISSING DATA?
df_unemployment_2004_19.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6

# %%
df_unemployment_2004_19.isna().any()
# Out:
# MONTH                     False
# UE_BENEFITS_WEB_SEARCH    False
# UNRATE                    False
# dtype: bool

# %%
# ANY MISSING DATA?
df_bitcoin_search_trend.head()
# Out:
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
df_bitcoin_search_trend.isna().any()
# Out:
# MONTH              False
# BTC_NEWS_SEARCH    False
# dtype: bool

# %%
# ANY MISSING DATA?
df_daily_bitcoin_price.head()
# Out:
#          DATE       CLOSE      VOLUME
# 0  2014-09-17  457.334015  21056800.0
# 1  2014-09-18  424.440002  34483200.0
# 2  2014-09-19  394.795990  37919700.0
# 3  2014-09-20  408.903992  36863600.0
# 4  2014-09-21  398.821014  26580100.0

# %%
df_daily_bitcoin_price.isna().any()
# Out:
# DATE      False
# CLOSE      True
# VOLUME     True
# dtype: bool

# %%
# ANOTHER WAY TO FIND MISSING VALUES IN TABLES:
print(f'Missing values for Tesla?: {df_tesla.isna().values.any()}')
print(f'Missing values for U/E?: {df_unemployment_2004_19.isna().values.any()}')
print(f'Missing values for BTC Search?: {df_bitcoin_search_trend.isna().values.any()}')
print(f'Missing values for Daily BTC price?: {df_daily_bitcoin_price.isna().values.any()}')
# Out:
# Missing values for Tesla?: False
# Missing values for U/E?: False
# Missing values for BTC Search?: False
# Missing values for Daily BTC price?: True

# %%
# However, for the Bitcoin price data, there seems to be a problem. There's a missing value somewhere.
# The number of missing values can be found by using .sum() to add up the number of occurrences of True in the series. 
# This shows that there are 2 missing values.

# To find the row where the missing values occur, we can create a subset of the DataFrame using .isna() once again:

# %% [markdown]
# # Find Number of Missing values:

# %%
print(f'Number of missing values for Daily BTC price?: {df_daily_bitcoin_price.isna().values.sum()}')
# Out:
# Number of missing values for Daily BTC price?: 2

# %% [markdown]
# # Find a Row with Missing values

# %%
df_daily_bitcoin_price[df_daily_bitcoin_price.CLOSE.isna()]
# Out:
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %% [markdown]
# # Remove a Missing value:

# %%
# To remove a missing value we can use .dropna(). The inplace argument allows to overwrite our DataFrame and means 
# we don't have to write:

# df_btc_price = df_btc_price.dropna():

df_daily_bitcoin_price.dropna(inplace=True)

# %%
print(f'Number of missing values for Daily BTC price?: {df_daily_bitcoin_price.isna().values.sum()}')
# Out:
# Number of missing values for Daily BTC price?: 0

# %% [markdown]
# # Data Type:

# %%
print(f'Data Type Tesla: {type(df_tesla["MONTH"][0])}')
print(f'Data Type Unemployment: {type(df_unemployment_2004_19["MONTH"][0])}')
print(f'Data Type BTC Search: {type(df_bitcoin_search_trend["MONTH"][0])}')
print(f'Data Type BTC Price: {type(df_daily_bitcoin_price["DATE"][0])}')
# Out:
# Data Type Tesla: <class 'str'>
# Data Type Unemployment: <class 'str'>
# Data Type BTC Search: <class 'str'>
# Data Type BTC Price: <class 'str'>

# %% [markdown]
# # Converting Strings to Data:

# %%
df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH)
print(f'Data Type Tesla: {type(df_tesla["MONTH"][0])}')
# Out:
# Data Type Tesla: <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df_unemployment_2004_19.MONTH = pd.to_datetime(df_unemployment_2004_19.MONTH)
df_bitcoin_search_trend.MONTH = pd.to_datetime(df_bitcoin_search_trend.MONTH)
df_daily_bitcoin_price.DATE = pd.to_datetime(df_daily_bitcoin_price.DATE)

# %%
print(f'Data Type BTC Price: {type(df_daily_bitcoin_price["DATE"][0])}')
# Out:
# Data Type BTC Price: <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df_daily_bitcoin_price["DATE"].head()
# Out:
# 0   2014-09-17
# 1   2014-09-18
# 2   2014-09-19
# 3   2014-09-20
# 4   2014-09-21
# Name: DATE, dtype: datetime64[ns]

# %% [markdown]
# # Resampling Time Series Data

# %%
# Next, we have to think about how to make our Bitcoin price and our Bitcoin search volume comparable. 
# Our Bitcoin price is daily data, but our Bitcoin Search Popularity is monthly data.

# %% [markdown]
# # Converting Daily Data into Monthly Data:

# %%
# To convert our daily data into monthly data, we're going to use the .resample() function. 
# The only things we need to specify is which column to use (i.e., our DATE column) and what kind of sample 
# frequency we want (i.e., the "rule"). We want a monthly frequency, so we use 'M'.  
# If you ever need to resample a time series to a different frequency, you can find a list of different options 
# here (for example 'Y' for yearly or 'T' for minute): 
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects.

# %%
# After resampling, we need to figure out how the data should be treated. 
# In our case, we want the last available price of the month - the price at month-end.

# %%
df_monthly_bitcoin_price = df_daily_bitcoin_price.resample('M', on='DATE').last()

# %%
df_monthly_bitcoin_price.head()
# Out:
#                  DATE       CLOSE      VOLUME
# DATE
# 2014-09-30 2014-09-30  386.944000  34707300.0
# 2014-10-31 2014-10-31  338.321014  12545400.0
# 2014-11-30 2014-11-30  378.046997   9194440.0
# 2014-12-31 2014-12-31  320.192993  13942900.0
# 2015-01-31 2015-01-31  217.464005  23348200.0

# %%
# If we wanted the average price over the course of the month, we could use something like:
df_monthly_bitcoin_price = df_daily_bitcoin_price.resample('M', on='DATE').mean()
df_monthly_bitcoin_price.head()
# Out:
#                  CLOSE        VOLUME
# DATE
# 2014-09-30  407.182428  2.934864e+07
# 2014-10-31  364.148873  2.912885e+07
# 2014-11-30  366.099799  2.199111e+07
# 2014-12-31  341.267871  1.784201e+07
# 2015-01-31  248.782547  3.544555e+07

# %%
df_monthly_bitcoin_price.shape
# Out:
# (73, 2)

# %%
# We have 73 rows in our price data - the same as our search data. Nice!

# %% [markdown]
# # Data Visualisation - Tesla Line Charts in Matplotlib

# %%
# Let's create a basic line chart of the Tesla stock price and the search popularity and then gradually add 
# more and more styling to our chart.

# Plot the Tesla stock price against the Tesla search volume using a line chart and two different axes:
import matplotlib.pyplot as plt

df_tesla.head()
# Out:
#        MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0 2010-06-01                3           4.766
# 1 2010-07-01                3           3.988
# 2 2010-08-01                2           3.896
# 3 2010-09-01                2           4.082
# 4 2010-10-01                2           4.368

# %% [markdown]
# # Chart with Tesla Price and Search values:

# %%
plt.plot(df_tesla.index, df_tesla.TSLA_USD_CLOSE)
plt.plot(df_tesla.index, df_tesla.TSLA_WEB_SEARCH)

# %% [markdown]
# # Chart with Tesla Price and Search values with separate Axis:

# %%
# We need to be able to configure and plot our data on two separate axes on the same chart. 
# This involves getting hold of an axis object from Matplotlib.

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

ax1.plot(df_tesla.index, df_tesla.TSLA_USD_CLOSE)
ax2.plot(df_tesla.index, df_tesla.TSLA_WEB_SEARCH)

# %%
# That's very nice! But there's one problem: we can't tell the lines apart because they have the same colour! 
# Let's add some styling. Let's:

# colour in the lines

# colour in the axes and

# add some labels

# so that we can see what's going on. Here's what we get:

# %%
ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH)

ax1.set_xlabel("year", fontsize = 14)
ax1.set_ylabel("TSLA Stock Price", color="g", fontsize = 14)
ax2.set_ylabel("Search Trend", color="r", fontsize = 14)
# Out:
# Text(0, 0.5, 'Search Trend')

# %% [markdown]
# # Styling the Chart with TSLA Price and Trend Search:

# %%
# Now let's style the chart a bit more. In particular, 
# let's check out the different colours you can use with Matplotlib.

# For our updated chart, let's differentiate the two lines and the axis labels using different colours. 
# Using one of the blue colour names for the search volume and a HEX code for a red colour for the stock price:

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='#E6232E')
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='skyblue')

# ax1.set_xlabel("year",  fontsize = 14)
ax1.set_ylabel("TSLA Stock Price",  color='#E6232E', fontsize = 14) # can use a HEX code
ax2.set_ylabel("Search Trend", color='skyblue', fontsize = 14) # or a named colour
# Out:
# Text(0, 0.5, 'Search Trend')

# %% [markdown]
# # Increase the Chart size (e.g., to 14 by 8).

# %%
plt.figure(figsize=(14, 8))  # make chart larger

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='#E6232E')
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='skyblue')

# ax1.set_xlabel("year",  fontsize = 14)
ax1.set_ylabel("TSLA Stock Price",  color='#E6232E', fontsize = 14) # can use a HEX code
ax2.set_ylabel("Search Trend", color='skyblue', fontsize = 14) # or a named colour
# Out:
# Text(0, 0.5, 'Search Trend')

# %% [markdown]
# # Increase the font sizes for the labels and the ticks on the x-axis to 14.

# %%
# increases size of chart and resolution
plt.figure(figsize=(14,8), dpi=120)

# Adding a chart title:
plt.title('Tesla Web Search vs Price', fontsize=18)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

# Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('TSLA Stock Price', color='#E6232E', fontsize=14)# can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)# or a named colour

ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='#E6232E', linewidth=3) # making a line thicker at the chart
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='skyblue', linewidth=3)

# Displays chart explicitly
plt.show()

# %% [markdown]
# # Adding Rotation to x-axes

# %%
# Here's the code with rotation added to the x-ticks. 
# With .set_ylim() and .set_xlim() you have precise control over which data you want to show on the chart. 
# You can either choose hard values like displaying the Tesla stock price between $0 and $600. 
# Or you could use the .min() and .max() functions to help you work out the bounds for the chart as well.


# increases size of chart and resolution
plt.figure(figsize=(14,8), dpi=120)

# Adding a chart title:
plt.title('Tesla Web Search vs Price', fontsize=18)

# Increase the size and rotate the labels on the x-axis
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

# Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('TSLA Stock Price', color='#E6232E', fontsize=14)# can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)# or a named colour

# Set the minimum and maximum values on the axes
ax1.set_ylim([0, 600])
ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])


ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='#E6232E', linewidth=3) # making a line thicker at the chart
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='skyblue', linewidth=3)

# Displays chart explicitly
plt.show()

# %% [markdown]
# # Using Locators and DateFormatters to generate Tick Marks on a Time Line

# %% [markdown]
# <h2>Adding Locator Tick Marks</h2>

# %%
# When working with time series, it's often quite difficult to get the tick marks on charts looking the way you want to. 
# This is why we have Locator helpers.
# Using Locators we can change our x-axis.

# %% [markdown]
# <h2> Importing matplotlib.dates: </h2>

# %%
# The first step is importing matplotlib.dates.  This is where all the date plotting capabilities live.

# %%
import matplotlib.dates as mdates

# %%
# Next, we need a YearLocator() and a MonthLocator() objects, which will help Matplotlib find the years and the months. 
# Then we also need a DateFormatter(), which will help us specify how we want to display the dates.

# %% [markdown]
# <h2>Create locators from ticks on the time axis: </h2>

# %%
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# %%
# Now we can go back to our chart and format where the major and minor ticks should be using the Locators.

# %%
# format the ticksax1.xaxis.set_major_locator(years)ax1.xaxis.set_major_formatter(years_fmt)ax1.xaxis.set_minor_locator(months)

# increases size of chart and resolution
plt.figure(figsize=(13,7), dpi=120)

# Adding a chart title:
plt.title('Tesla Web Search vs Price', fontsize=18)

# Increase the size and rotate the labels on the x-axis
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

# format the ticks using locators:
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('TSLA Stock Price', color='#E6232E', fontsize=14)# can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)# or a named colour

# Set the minimum and maximum values on the axes
ax1.set_ylim([0, 600])
ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])


ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='#E6232E', linewidth=3) # making a line thicker at the chart
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='skyblue', linewidth=3)

# Displays chart explicitly
plt.show()

# %% [markdown]
# When we take a look at our chart, we can see the tick marks nicely. The tick marks also allow us to visually date that spike of interest in the middle of the chart - March 2016. This was when the Tesla Model 3 was unveiled. Also, we can clearly see that the most recent spikes in search coincide, not with the release of a new car, but the roaring stock price for the company!

# %% [markdown]
# # Data Visualisation - Bitcoin: Line Style and Markers

# %%
# Now that we've got Tesla looking the way we want it to, let's do the same for Bitcoin. 

# 1. Modify the chart title to read 'Bitcoin News Search vs Resampled Price'

# 2. Change the y-axis label to 'BTC Price'

# 3. Change the y- and x-axis limits to improve the appearance

# 4. Investigate the linestyles to make the BTC closing price a dashed line

# 5. Investigate the marker types to make the search datapoints little circles

# 6. Were big increases in searches for Bitcoin accompanied by big increases in the price?

# %%
df_monthly_bitcoin_price.head()
# Out:
#                  CLOSE        VOLUME
# DATE
# 2014-09-30  407.182428  2.934864e+07
# 2014-10-31  364.148873  2.912885e+07
# 2014-11-30  366.099799  2.199111e+07
# 2014-12-31  341.267871  1.784201e+07
# 2015-01-31  248.782547  3.544555e+07

# %%
df_bitcoin_search_trend.head()
# Out:
#        MONTH  BTC_NEWS_SEARCH
# 0 2014-09-01                5
# 1 2014-10-01                4
# 2 2014-11-01                4
# 3 2014-12-01                4
# 4 2015-01-01                5

# %%
# # increases size of chart and resolution
plt.figure(figsize=(13,7), dpi=120)

# # Adding a chart title:
plt.title('Bitcoin News Search vs Resampled Price', fontsize=18)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

# # Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('BTC Price', color='#E6232E', fontsize=14)# can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)# or a named colour

ax1.plot(df_monthly_bitcoin_price.index, df_monthly_bitcoin_price.CLOSE, color='#E6232E', linewidth=3) # making a line thicker at the chart
ax2.plot(df_monthly_bitcoin_price.index, df_bitcoin_search_trend.BTC_NEWS_SEARCH, color='skyblue', linewidth=3)

# %% [markdown]
# # Changing the line style:

# %%
# To change the line style or the markers, you just have to look at the documentation 
# (e.g., try '--' or '-.' for the linestyle). 
# https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html

# The first step is importing matplotlib.dates.  This is where all the date plotting capabilities live.
import matplotlib.dates as mdates

# Next, we need a YearLocator() and a MonthLocator() objects, which will help Matplotlib find the years and the months. 
# Then we also need a DateFormatter(), which will help us specify how we want to display the dates.
# Creating locators:
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# # increases size of chart and resolution
plt.figure(figsize=(13,7), dpi=120)

# Rotation of x font:
plt.xticks(fontsize=14, rotation=45)

# # Adding a chart title:
plt.title('Bitcoin News Search vs Resampled Price', fontsize=18)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

# # Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('BTC Price', color='#F08F2E', fontsize=14)# can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)# or a named colour

# # format the ticks using locators:
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# # Set the minimum and maximum values on the axes
ax1.set_ylim(bottom=0, top=15000)
ax1.set_xlim([df_monthly_bitcoin_price.index.min(), df_monthly_bitcoin_price.index.max()])

# # Experiment with the linestyle and markers
ax1.plot(df_monthly_bitcoin_price.index, df_monthly_bitcoin_price.CLOSE, color='#F08F2E', linewidth=3, linestyle='--') # making a line thicker at the chart
ax2.plot(df_monthly_bitcoin_price.index, df_bitcoin_search_trend.BTC_NEWS_SEARCH, color='skyblue', linewidth=3, marker='o')

# %% [markdown]
# What we see in the chart is that similar to Tesla, the crazy price movements in the beginning of 2018 are associated with very high search volumes. Everyone was talking about (and buying) Bitcoin in late 2017/early 2018 so search volumes were at a record high!  Interestingly, there was quite a huge spike in bitcoin prices in Q1 of 2019, but this time the increase in search volume was much less pronounced (perhaps because at this point everyone knew what Bitcoin was).

# %% [markdown]
# # Data Visualisation - Unemployment: How to use Grids

# %%
# How to add a grid to the chart to better see the years and the U/E rate values:
# https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.grid.html

# %%
df_unemployment_2004_19.head()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0 2004-01-01                      34     5.7
# 1 2004-02-01                      33     5.6
# 2 2004-03-01                      25     5.8
# 3 2004-04-01                      29     5.6
# 4 2004-05-01                      23     5.6

# %%
# To change the line style or the markers, you just have to look at the documentation 
# (e.g., try '--' or '-.' for the linestyle). 
# https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html

# The first step is importing matplotlib.dates.  This is where all the date plotting capabilities live.
import matplotlib.dates as mdates
import matplotlib.pyplot as plt



# Next, we need a YearLocator() and a MonthLocator() objects, which will help Matplotlib find the years and the months. 
# Then we also need a DateFormatter(), which will help us specify how we want to display the dates.
# Creating locators:
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# # increases size of chart and resolution
plt.figure(figsize=(13,7), dpi=120)

# # Adding a chart title:
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate', fontsize=18)

# Adding a grid to chart:
plt.grid(b=None, which='major', axis='both', color='grey', linestyle='--')


# Increase the size and rotate the labels on the x-axis
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

# # Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)# can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)# or a named colour

# # format the ticks using locators:
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# # Set the minimum and maximum values on the axes
ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment_2004_19.MONTH.min(), df_unemployment_2004_19.MONTH.max()])


# # Set the minimum and maximum values on the axes
# ax1.set_ylim(bottom=0, top=15000)
# ax1.set_xlim([df_monthly_bitcoin_price.index.min(), df_monthly_bitcoin_price.index.max()])

# # Experiment with the linestyle and markers
ax1.plot(df_unemployment_2004_19.MONTH, df_unemployment_2004_19.UNRATE, color='purple', linewidth=3, linestyle='--') # making a line thicker at the chart
ax2.plot(df_unemployment_2004_19.MONTH, df_unemployment_2004_19.UE_BENEFITS_WEB_SEARCH, color='skyblue', linewidth=3)

plt.show()

# %% [markdown]
# Notice how we can now clearly see the vertical dashed lines line up with spikes in searches for "Unemployment benefits". Many of the spikes are at year-end - in December. This clearly shows that there is seasonality in the job market. What else do we see? We see that the financial crisis in 2007/2008 caused a massive spike in unemployment. It took around 10 years (2007-2017) for the unemployment to reach the same level it had before the crisis.

# %% [markdown]
# Interestingly the big spike in searches for Unemployment benefits at the end of 2013 was not accompanied by a big increase in the unemployment rate. Something else must have been going on around that time.

# %% [markdown]
# # Rolling Average

# %%
# You can create a rolling average using .rolling() and .mean() functions together.

# %%
# Next, we need a YearLocator() and a MonthLocator() objects, which will help Matplotlib find the years and the months. 
# Then we also need a DateFormatter(), which will help us specify how we want to display the dates.
# Creating locators:
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# # increases size of chart and resolution
plt.figure(figsize=(13,7), dpi=120)

# # Adding a chart title:
plt.title('Rolling Monthly US "Unemployment Benefits" Web Searches vs UNRATE', fontsize=18)

# Adding a grid to chart:
plt.grid(b=None, which='major', axis='both', color='grey', linestyle='--')


# Increase the size and rotate the labels on the x-axis
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

# # Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)# can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)# or a named colour

# # format the ticks using locators:
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# # Set the minimum and maximum values on the axes
ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment_2004_19.MONTH.min(), df_unemployment_2004_19.MONTH.max()])

# Calculate the rolling average over a 6 month window
roll_df = df_unemployment_2004_19[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()


# # Experiment with the linestyle and markers
ax1.plot(df_unemployment_2004_19.MONTH, roll_df.UNRATE, color='purple', linewidth=3, linestyle='--') # making a line thicker at the chart
ax2.plot(df_unemployment_2004_19.MONTH, roll_df.UE_BENEFITS_WEB_SEARCH, color='skyblue', linewidth=3)

plt.show()

# %% [markdown]
# What is this telling us? We see that searches for "Unemployment Benefits" happen before the actual official unemployment rate goes up. Similarly, the search popularity for the term goes down before the unemployment rate decreases. In other words, these searches seem to act as a leading economic indicator for the unemployment rate (which is a lagging indicator).

# %% [markdown]
# # Data Visualisation - Unemployment: The Effect of New Data 2020

# %% [markdown]
# The financial crisis in 2008 was pretty bad. We saw how it took around 10 years for the unemployment rate to go back to where it was prior to the crisis.
#
# Let's see how 2020 affects our analysis.

# %%
#  Lets read the data in the 'UE Benefits Search vs UE Rate 2004-20.csv' into a DataFrame. 
# Lets convert the MONTH column to Pandas Datetime objects and then plot the chart. What do we see?

df_unemployment_2004_20 = pd.read_csv('D:\\Desktop\\Study\\100 Days of Code - The Complete Python Pro Bootcamp for 2021\\DATA\\Google Trends\\UE Benefits Search vs UE Rate 2004-20.csv')
df_unemployment_2004_20.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                       9     5.7
# 1  2004-02                       8     5.6
# 2  2004-03                       7     5.8
# 3  2004-04                       8     5.6
# 4  2004-05                       6     5.6

# %%
df_unemployment_2004_20.tail()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 195  2020-04                     100    14.7
# 196  2020-05                      63    13.3
# 197  2020-06                      53    11.1
# 198  2020-07                      54    10.2
# 199  2020-08                      50     8.4

# %% [markdown]
# <h2>Checking the data type:</h2>

# %%
# Type of MONTH column:
print(f'Data Type Unemployment 2020: {type(df_unemployment_2004_20["MONTH"][0])}')
# Out:
# Data Type Unemployment 2020: <class 'str'>

# %% [markdown]
# <h2>Converting the string into date:</h2>

# %%
df_unemployment_2004_20.MONTH = pd.to_datetime(df_unemployment_2004_20.MONTH)

# %%
print(f'Data Type Unemployment 2020: {type(df_unemployment_2004_20["MONTH"][0])}')
# Out:
# Data Type Unemployment 2020: <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# <h2>Creating Chart for Unemployment in 2020</h2>

# %%
# To change the line style or the markers, you just have to look at the documentation 
# (e.g., try '--' or '-.' for the linestyle). 
# https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html

# The first step is importing matplotlib.dates.  This is where all the date plotting capabilities live.
import matplotlib.dates as mdates
import matplotlib.pyplot as plt



# Next, we need a YearLocator() and a MonthLocator() objects, which will help Matplotlib find the years and the months. 
# Then we also need a DateFormatter(), which will help us specify how we want to display the dates.
# Creating locators:
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# # increases size of chart and resolution
plt.figure(figsize=(13,7), dpi=120)

# # Adding a chart title:
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate', fontsize=18)

# Adding a grid to chart:
plt.grid(b=None, which='major', axis='both', color='grey', linestyle='--')


# Increase the size and rotate the labels on the x-axis
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx()  # create another axis that shares the same x-axis

# # Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)# can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)# or a named colour

# # format the ticks using locators:
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# # Set the minimum and maximum values on the axes
ax1.set_ylim(bottom=0, top=30)
ax1.set_xlim([df_unemployment_2004_20.MONTH.min(), df_unemployment_2004_20.MONTH.max()])


# # Experiment with the linestyle and markers
ax1.plot(df_unemployment_2004_20.MONTH, df_unemployment_2004_20.UNRATE, color='purple', linewidth=3, linestyle='--') # making a line thicker at the chart
ax2.plot(df_unemployment_2004_20.MONTH, df_unemployment_2004_20.UE_BENEFITS_WEB_SEARCH, color='skyblue', linewidth=3)

plt.show()

# %% [markdown]
# What we see is not pretty. The US unemployment rate spiked to unprecedented levels during the COVID pandemic, dwarfing the levels seen during the financial crisis. Let's hope the recovery will be swifter this time.
